# %% [markdown]
# # DCCS Task Flow Diagram Generator
#
# This notebook generates a publication-ready flowchart for the DCCS (Dimensional Change Card Sort) task workflow.
#
# **Output formats:** PNG (high-res), PDF (vector), SVG (scalable)

# %%
# Install required packages (if not already installed)
# !pip install -q matplotlib numpy

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.patches import FancyBboxPatch, FancyArrowPatch
import numpy as np

# Set style for publication-quality figures
plt.style.use('default')
plt.rcParams.update({
    'font.family': 'sans-serif',
    'font.size': 10,
    'figure.dpi': 300,
    'savefig.dpi': 300,
    'savefig.bbox': 'tight',
    'savefig.facecolor': 'white',
    'savefig.edgecolor': 'none'
})

# %%
# Copy the complete function from generate_dccs_flow_diagram.py
# Or run: %run generate_dccs_flow_diagram.py

# For now, we'll define it here:
exec(open('generate_dccs_flow_diagram.py').read().split('if __name__')[0])

# %%
# Generate the diagram (all formats: PNG, PDF, SVG)
create_dccs_flow_diagram(output_format='all', dpi=300)
